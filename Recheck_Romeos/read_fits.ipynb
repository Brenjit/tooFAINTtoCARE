# %%
from astropy.io import fits

# === Define the file path ===
file_path = '/Volumes/MY_SSD_1TB/Work_PhD/July-August/CEERS_data/nircam1/egs_all_acs_wfc_f606w_030mas_v1.9_nircam1_mef.fits'  # 🔁 Replace with actual path

# === Print general info about all HDUs ===
print("🔍 FITS File Structure:")
fits.info(file_path)
print("=" * 60)

# === Open the file and inspect each HDU ===
with fits.open(file_path) as hdul:
    for idx, hdu in enumerate(hdul):
        print(f"\n--- HDU {idx} ---")
        print(f"Type: {type(hdu)}")
        print(f"Header:\n{hdu.header}")
        
        # Try to print data shape/type if present
        if hdu.data is not None:
            print(f"Data type: {type(hdu.data)}")
            print(f"Data shape: {hdu.data.shape}")
        else:
            print("No data in this HDU.")
# Out:
# 🔍 FITS File Structure:
# Filename: /Volumes/MY_SSD_1TB/Work_PhD/July-August/CEERS_data/nircam1/egs_all_acs_wfc_f606w_030mas_v1.9_nircam1_mef.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU   12978   ()
#   1  SCI_BKSUB     1 ImageHDU        40   (10600, 4800)   float64
#   2  SCI           1 ImageHDU        40   (10600, 4800)   float32
#   3  RMS           1 ImageHDU         8   (10600, 4800)   float32
#   4  BKGD          1 ImageHDU        40   (10600, 4800)   float64
#   5  BKGMASK       1 ImageHDU        39   (10600, 4800)   float32
# ...
#
# --- HDU 0 ---
# Type: <class 'astropy.io.fits.hdu.image.PrimaryHDU'>
# Header:
# ...

# %%
from astropy.io import fits

# === Define the file path ===
file_path = '/Volumes/MY_SSD_1TB/Work_PhD/July-August/CEERS_data/nircam1/hlsp_ceers_jwst_nircam_nircam1_f200w_dr0.5_i2d.fits'  # 🔁 Replace with actual path

# === Print general info about all HDUs ===
print("🔍 FITS File Structure:")
fits.info(file_path)
print("=" * 60)

# === Open the file and inspect each HDU ===
with fits.open(file_path) as hdul:
    for idx, hdu in enumerate(hdul):
        print(f"\n--- HDU {idx} ---")
        print(f"Type: {type(hdu)}")
        print(f"Header:\n{hdu.header}")
        
        # Try to print data shape/type if present
        if hdu.data is not None:
            print(f"Data type: {type(hdu.data)}")
            print(f"Data shape: {hdu.data.shape}")
        else:
            print("No data in this HDU.")
# Out:
# 🔍 FITS File Structure:
# Filename: /Volumes/MY_SSD_1TB/Work_PhD/July-August/CEERS_data/nircam1/hlsp_ceers_jwst_nircam_nircam1_f200w_dr0.5_i2d.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     374   ()
#   1  SCI_BKSUB     1 ImageHDU        75   (10600, 4800)   float64
#   2  SCI           1 ImageHDU        75   (10600, 4800)   float32
#   3  ERR           1 ImageHDU        10   (10600, 4800)   float32
#   4  CON           1 ImageHDU         9   (10600, 4800)   int32
#   5  WHT           1 ImageHDU         9   (10600, 4800)   float32
#   6  VAR_POISSON    1 ImageHDU         9   (10600, 4800)   float32
#   7  VAR_RNOISE    1 ImageHDU         9   (10600, 4800)   float32
#   8  VAR_FLAT      1 ImageHDU         9   (10600, 4800)   float32
#   9  BKGD          1 ImageHDU        39   (10600, 4800)   float64
#  10  BKGMASK       1 ImageHDU        39   (10600, 4800)   float32
# ...
